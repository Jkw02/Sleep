# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


df = pd.read_csv('Downloads/Dataset_for_project.csv')
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
#This shows that there are two values which are the same just named differently, Normal and Normal Weight. 
(df['BMI Category']).value_counts()
# Out:
# Normal           195
# Overweight       148
# Normal Weight     21
# Obese             10
# Name: BMI Category, dtype: int64

# %%
#This shows there are two values which are named very simularly Salesperson and Sales Representative. 
(df['Occupation']).value_counts()
# Out:
# Nurse                   73
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Software Engineer        4
# Scientist                4
# Sales Representative     2
# Manager                  1
# Name: Occupation, dtype: int64

# %% [markdown]
# The intial dataset shows that there are a
# The cleaning that was done on the dataset was:
#  -Checked for null values in the data, these would not want to be used as they dont provide any information
#  -The BMI category had a value of Normal and a value of Normal Weight, these have been combinated as they come under the same category.
#  -The blood pressure category has been seperated into two different columns to be able to use the data for anyalst. There is a column for Systolic Blood Pressure and a column for Diastolic Blood Pressure.
#  -A weight category has been added to categorise the BMI column to give each value a number.
#  -The occupation column has been cleaned by combining sales representative and salesperson. A job category column has then been added to group the jobs by titles.

# %%
#The cleaned data set
#This is the dataset which is going to be used going fowards. 
clean_df = pd.read_csv('Downloads/CLEAN_Sleep_health_and_lifestyle_dataset.csv')
clean_df
# Out:
#      Person ID  Gender  Age            Occupation            Job category  \
# 0            1    Male   27     Software Engineer  Science and Technology
# 1            2    Male   28                Doctor              Healthcare
# 2            3    Male   28                Doctor              Healthcare
# 3            4    Male   28  Sales Representative     Business Management
# 4            5    Male   28  Sales Representative     Business Management
# ..         ...     ...  ...                   ...                     ...
# 369        370  Female   59                 Nurse              Healthcare
# 370        371  Female   59                 Nurse              Healthcare
# 371        372  Female   59                 Nurse              Healthcare
# 372        373  Female   59                 Nurse              Healthcare
# 373        374  Female   59                 Nurse              Healthcare
#
#      Sleep Duration  Quality of Sleep  Physical Activity Level  Stress Level  \
# ...

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Person ID                 374 non-null    int64
#  1   Gender                    374 non-null    object
#  2   Age                       374 non-null    int64
#  3   Occupation                374 non-null    object
#  4   Job category              374 non-null    object
#  5   Sleep Duration            374 non-null    float64
#  6   Quality of Sleep          374 non-null    int64
#  7   Physical Activity Level   374 non-null    int64
#  8   Stress Level              374 non-null    int64
#  9   BMI Category              374 non-null    object
#  10  Weight Category           374 non-null    int64
#  11  Systolic Blood Pressure   374 non-null    int64
#  12  Diastolic Blood Pressure  374 non-null    int64
#  13  Heart Rate                374 non-null    int64
# ...

# %% [markdown]
# This shows what the types of data are used within the dataset. It shows that most of the columns have integears which is shown by int64. There are few columns with object which mean they will have a non-numerical value. These columns will not be able to be used for any numerical anaylst for example correlation.

# %%
#create a dataset which just includes the columns of numerical data
numerical_columns = clean_df.select_dtypes(include=[np.int64,np.float64])
#drop the column 'Person ID' as this is not useful 
numerical_columns = numerical_columns.drop('Person ID', axis=1)
numerical_columns
# Out:
#      Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# 0     27             6.1                 6                       42
# 1     28             6.2                 6                       60
# 2     28             6.2                 6                       60
# 3     28             5.9                 4                       30
# 4     28             5.9                 4                       30
# ..   ...             ...               ...                      ...
# 369   59             8.1                 9                       75
# 370   59             8.0                 9                       75
# 371   59             8.1                 9                       75
# 372   59             8.1                 9                       75
# 373   59             8.1                 9                       75
#
#      Stress Level  Weight Category  Systolic Blood Pressure  \
# 0               6                2                      126
# ...

# %%
#create a heatmap to show the null values of the dataset
plt.figure(1,figsize=(10,10))
sns.heatmap(clean_df.isnull(),cbar=False,yticklabels=False)
plt.title("Heatmap of the Null Values in the Dataset")
plt.xlabel('Variables')
plt.ylabel('Variables')
plt.show()

# %% [markdown]
# The complete blank heatmap shows that there are no null values in any columns of the dataset.

# %%
#plot to compare the occupation category from the orginal dataset to the clean dataset. 
plt.figure(2,figsize=(15,15))
counts = df['Occupation'].value_counts()#get the number workers from each occupation
unique = df['Occupation'].unique() #get the name of each occupation
plt.subplot(1,2,1)
plt.pie(counts) #plot the pie chart 
plt.title('Occupation') #title the graph 
plt.legend([unique[0],unique[1],unique[2],unique[3],unique[4],unique[5],unique[6],unique[7],unique[8],unique[9],unique[10]],loc = 'upper left',prop = {'size' : 6})


counts = clean_df['Job category'].value_counts() #get the number workers from each categorys 
unique = clean_df['Job category'].unique() # get the name of each category
plt.subplot(1,2,2)
plt.pie(counts) #plot the pie chart 
plt.title('Job category') #title the graph 
plt.legend([unique[0],unique[1],unique[2],unique[3],unique[4]],loc = 'upper left',prop = {'size' : 6})


plt.suptitle("Pie Charts to Compare the Occupations from the Orginal Data to Cleaned Data")
plt.show()

# %% [markdown]
# By grouping the occupations into categorys it is much easier to visulise the data. From the pie chart on the left it shows there are lots of different occupations making the pie chart become quite clustered. The chart on the right is once the occupations have been grouped, it is much more clear to read as there are less groups plotted.
#
# Overall the chart shows that science and technology have the most number of people working within that group, taking over a quater of the whole graph. The next largest category is Health care and the category which consists of doctors and nurses. The two smallest categorys are education and professional services and they are very close toghther in terms of number of workings, its very hard to tell from the graph which one has less.

# %%
clean_df.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Weight Category  \
# count               374.000000    374.000000       374.000000
# mean                 59.171123      5.385027         1.449198
# std                  20.830804      1.774526         0.549274
# min                  30.000000      3.000000         1.000000
# 25%                  45.000000      4.000000         1.000000
# ...

# %% [markdown]
# The table above shows different measures of the data such as the min, max interquaile range and mean.
# The count values count how many values are in each column. Each column has 374 values resulting in 374 people in the dataset. As each column has the same number of values it means there are no null values in the dataset.
#
# The mean values display the average for that column, for example the mean value for heart rate is 70.17.
#
# Comparing the min and max values it shows the span of the data in that column. There are not any columns which have a huge difference, the column with the largest is daily steps as the min is 3000 and max is 10000.
#
# When looking at the max values there is no large difference between them and the 75% percentile. This shows there are no large outliers in the data. The min can also be compared to the 25% percentile to also look for outliers. A graph to visulise this would be a box plot.

# %%
plt.figure(3,figsize=(15,15))
plt.boxplot(numerical_columns,list(numerical_columns))
plt.xlabel('Variable') # label the x asis
plt.ylabel('Value') #label the y axis 
plt.title('Box Plot of The Data') #title the graph 

plt.show()

# %% [markdown]
# When each boxplot for the variables is plotted agaisnt each other it is very hard to read as the values for the last box plot are larger than the others so it plots the graph alot higher on the y axis.

# %%
#plot all boxplots eliminating daily steps to see if the graph is easier to read
plt.figure(4,figsize=(15,15))
plt.boxplot(numerical_columns.drop('Daily Steps', axis=1),(list(numerical_columns)))
plt.xlabel('Variable') # label the x asis
plt.ylabel('Value') #label the y axis 
plt.title('Box Plot Of The Data Without Daily Steps') #title the graph 

plt.show()

# %% [markdown]
# When eliminating the daily steps box plot it is much easier to read the other ones as they have more simular values to be plotted on the y axis. These box plots show the distribution of the data. The longer the box plot the larger the range of data, for box plot 4 which is the physical activity the length of the box plot is larger suggesting there is a large range of pysical activity. These plots show that the last box plot does have some points plotted after the box plot which does suggest there are some outliers within the data.

# %%
numerical_columns.corr()
# Out:
#                                Age  Sleep Duration  Quality of Sleep  \
# Age                       1.000000        0.344709          0.473734
# Sleep Duration            0.344709        1.000000          0.883213
# Quality of Sleep          0.473734        0.883213          1.000000
# Physical Activity Level   0.178993        0.212360          0.192896
# Stress Level             -0.422344       -0.811023         -0.898752
# Weight Category           0.427704       -0.349605         -0.324413
# Systolic Blood Pressure   0.605878       -0.180406         -0.121632
# Diastolic Blood Pressure  0.593839       -0.166570         -0.110151
# Heart Rate               -0.225606       -0.516455         -0.659865
# Daily Steps               0.057973       -0.039533          0.016791
#
#                           Physical Activity Level  Stress Level  \
# Age                                      0.178993     -0.422344
# Sleep Duration                           0.212360     -0.811023
# ...

# %% [markdown]
# The table above shows the correlation between each of the variables. The closer the correlation is to 1 or -1 the stronger the correlation is and the closer to correlation is to 0 the weaker the correlation. If the correlation between two variables is 0 then we can say they have no correlation between each other. If the correlation is postive it suggests as one variable increases/ decreases so does the other. A negative correlation suggests as one variable increases the other one will decreases and vise versa. The leading diagnol is one as it is the same variable agaisnt each other.
#
# A chart that can be used to visualy see the correlation would be a heatmap.

# %%
plt.figure(5,figsize=(15,15))
# #annot =True - add the correlation figure in each box on the graph
# #cmap="YlGnBu" - gives the colour of the graph 
# #linewidth=0.2 - the width of the lines between eah box 
# #square =True - the graph will be plotted as a sqaure 
sns.heatmap(numerical_columns.astype(float).corr(),annot=True, cmap="YlGnBu",linewidth=0.2,square=True)
plt.title("Heatmap of the Correlation Between Each Variable")
plt.xlabel('Variables')
plt.ylabel('Variables')
plt.show()

# %% [markdown]
# As shown by the colour chart to the right of the graph the lighter the colour the more negative the correlation and the darker the colour the more positive the correlation. Looking at the graph the two variables with the strongest postive correlation is systolic blood pressure and Diastolic blood pressure. This suggests as one increases so does the other. This would make sense as they are both linked to your blood pressure. The weakest correlation is between quality of sleep and daily steps, this is 0.017. This suggests there is no correlation with somebody having more sleep and more/less daily steps.
#
# Another high correlation is between sleep duration and quality of sleep which is 0.88. As this is a positive correlation it suggests as sleep duration increases so does the quality of sleep.
#
# Stress level and quality of sleep are strongly negativly correlated, suggesting as one increases the other will decrease.

# %%
#scatter plot of Weakest and Strongest Correlated Variables found from the heatmap above

plt.figure(6,figsize=(10,10))
plt.subplot(2,1,1)
plt.scatter(x = clean_df['Systolic Blood Pressure'],y =clean_df['Diastolic Blood Pressure'] )
plt.xlabel('Systolic Blood Pressure')
plt.ylabel('Diastolic Blood Pressure')
plt.title('Systolic Blood Pressure against Diastolic Blood Pressure')

plt.subplot(2,1,2)
plt.scatter(x = clean_df['Daily Steps'],y =clean_df['Quality of Sleep'] )
plt.xlabel('Daily Steps')
plt.ylabel('Quality of Sleep')
plt.title('Daily Steps agaisnt Quality of Sleep')

plt.suptitle("Scatter Plots of the Weakest and Strongest Correlated Variables")
plt.show()

# %% [markdown]
# From the scatter plot above it is clear the difference between strongly correlated variables and weakly correlated variables. The first scatter plot which shows the correlation betweeen Systolic Blood Pressure against Diastolic Blood Pressure shows as one increase so does the other. However in the second plot od quality of sleep agaisnt daily steps there is no correlation. The plots in the graph are plotted all over the graph and no trend can be found.

# %%
#get the correlation of each variable agaisnt sleep duration and sleep quality

sleep_cor = numerical_columns.corr(method="pearson")['Sleep Duration']
sleep_quality_cor = numerical_columns.corr(method="pearson")['Quality of Sleep']

# %%
col_names = list(numerical_columns.columns)

plt.figure(7,figsize = (20,20))
plt.subplot(2,1,1)
plt.scatter(col_names,sleep_cor)
plt.xlabel('Variable')
plt.ylabel('Correlation')
plt.title('The Correlation of Each Variable Agaisnt Sleep Duration')
plt.subplot(2,1,2)
plt.scatter(col_names,sleep_quality_cor)
plt.xlabel('Variable')
plt.ylabel('Correlation')
plt.title('The Correlation of each variable agaisnt sleep duration')
plt.suptitle("Correlation Between two Sleep Variables")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The two scatter plots above shows the correlation of each variable against sleep duration and sleep quality. The highest correlation for both variables were each other, for example for sleep duration it was quality of sleep and for quality of sleep it was sleep duration. Another highly correlation variable for both sleep variables was stress. This was highly negativly correlated suggesting as your stress levels increase your sleep qaulity and duration will descrease.
#
# The weakest correlation for both variables was both blood pressure variables. This suggest your blood pressure doesnt have much effect on your sleep.

# %%
# #create a list of each of the column names 
col_names = list(numerical_columns.columns)

 #create a for loop to plot each histogram on the same plot 
for i in range(0,len(numerical_columns.columns)):
     plt.figure(8,figsize=(12,12))
     plt.subplot(3,4,i+1)    #subplot so each graph is fitted on the same figure
     plt.hist(numerical_columns[col_names[i]]) #plot the histogram 
     plt.xlabel(col_names[i]) #label each of the x axises 
     plt.ylabel('Count')
     plt.tight_layout() #sizes the histograms so all the x axis can be seen 

plt.suptitle("Histograms of each numerical data column")
plt.show()

# %% [markdown]
# The histograms above give an idea of the data that is within the dataset and if there are any trends. The first histogram shows that the most common age within the data set is around 45 with that reaching almost 80 people. The weight category shows that the most common group is 1 which is normal. The heart rate histogram shows there is a dip after 75 showing that the most popular heart rate is from 65 to 75 with a huge drop after that.

# %%
# Grouping data by 'Age' and calculating the average sleep duration for each age group
average_sleep_duration = clean_df.groupby('Age')['Sleep Duration'].mean().reset_index()

# Create a dictionary to map age groups to numerical values for plotting
age_mapping = {age: i for i, age in enumerate(average_sleep_duration['Age'])}

# Map age groups to numerical values in a new column 'AgeNumeric'
average_sleep_duration['AgeNumeric'] = average_sleep_duration['Age'].map(age_mapping)

# %%
# Plotting a bar graph for average sleep duration per age group
plt.figure(9,figsize=(10, 6))
plt.bar(average_sleep_duration['AgeNumeric'], average_sleep_duration['Sleep Duration'], color='skyblue')
plt.title('Average Sleep Duration per Age Group')
plt.xlabel('Age Group')
plt.ylabel('Average Sleep Duration (hours)')
plt.xticks(average_sleep_duration['AgeNumeric'], average_sleep_duration['Age'], rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# The graph above breaks down the ages of the data agaisnt sleep duration. It shows that the age group with the highest amount of sleep are 53-54 years old whilst the age groups with the least amount of sleep are 34 and 50.

# %%
# Grouping data by 'Occupation' and calculating the average sleep duration for each occupation
avg_sleep_duration = clean_df.groupby('Occupation')['Sleep Duration'].mean().reset_index()

# Sorting the values by average sleep duration in descending order
avg_sleep_duration = avg_sleep_duration.sort_values(by='Sleep Duration', ascending=False)

# Plotting a bar chart for average sleep duration per occupation
plt.figure(figsize=(10, 6))
plt.bar(avg_sleep_duration['Occupation'], avg_sleep_duration['Sleep Duration'], color='skyblue')
plt.title('Average Sleep Duration per Occupation')
plt.xlabel('Occupation')
plt.ylabel('Average Sleep Duration (hours)')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# This bar graph shows the average sleep duration split by the occuaptions. It shows that the occuaption of an engineer has the highest average sleep whilst the job of a scientist has the least average sleep.
